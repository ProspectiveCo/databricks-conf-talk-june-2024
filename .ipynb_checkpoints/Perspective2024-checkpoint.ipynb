# %%
from ipywidgets import VBox, HBox
from pyspark.sql import SparkSession
from perspective import PerspectiveWidget

from helpers.data import (
    HOST,
    MACHINES_PORT,
    USAGE_PORT,
    STATUS_PORT,
    JOBS_PORT,
)
from helpers.spark import (
    MACHINE_SCHEMA,
    MACHINE_SCHEMA_SPARK,
    USAGE_SCHEMA,
    USAGE_SCHEMA_SPARK,
    STATUS_SCHEMA,
    STATUS_SCHEMA_SPARK,
    JOBS_SCHEMA,
    JOBS_SCHEMA_SPARK,
)

# %%
# Important imports
from helpers.spark import (
    get_df_from_server,
    push_to_perspective,
)
from helpers.fastapi import (
    perspective_spark_bridge,
    start_server,
)

# %%
from helpers.data import machines, usage

# %%
m = machines()

# %%
u = usage(u)
u
# Out:
# {'machine_id': '5b361c4e5718',
#  'kind': 'worker',
#  'cores': 64,
#  'region': 'eu',
#  'zone': 'C',
#  'cpu': 88.47,
#  'mem': 100,
#  'free': 0,
#  'network': 91.78,
#  'disk': 98.4}

# %%
spark = SparkSession.builder.appName("Perspective Demo").getOrCreate()
# Out:
# 24/06/07 17:02:27 WARN Utils: Your hostname, mbp-m1 resolves to a loopback address: 127.0.0.1; using 10.0.1.10 instead (on interface en0)
# 24/06/07 17:02:27 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/06/07 17:02:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Get spark streaming dfs
machines_df = get_df_from_server(spark, MACHINE_SCHEMA_SPARK, HOST, MACHINES_PORT)
usage_df = get_df_from_server(spark, USAGE_SCHEMA_SPARK, HOST, USAGE_PORT)
status_df = get_df_from_server(spark, STATUS_SCHEMA_SPARK, HOST, STATUS_PORT)
jobs_df = get_df_from_server(spark, JOBS_SCHEMA_SPARK, HOST, JOBS_PORT)
# Out:
# 24/06/07 17:02:48 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.
# 24/06/07 17:02:48 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.
# 24/06/07 17:02:48 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.
# 24/06/07 17:02:48 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.

# %%
# construct 4 separate perspective widgets. Each will have its own table internally
machines_widget = PerspectiveWidget(MACHINE_SCHEMA, index="machine_id", settings=False)
usage_widget = PerspectiveWidget(USAGE_SCHEMA, index="machine_id", settings=False)
status_widget = PerspectiveWidget(STATUS_SCHEMA, index="machine_id", sort=[["last_update", "desc"]], settings=False)
jobs_widget = PerspectiveWidget(JOBS_SCHEMA, sort=[["start_time", "desc"]], settings=False)

# %%
# a little bit of layout with ipywidgets
VBox(children=[
    HBox(children=[machines_widget, usage_widget]),
    HBox(children=[status_widget, jobs_widget]),
])
# Out:
# VBox(children=(HBox(children=(PerspectiveWidget(columns=['machine_id', 'kind', 'cores', 'region', 'zone'], set…
# 24/06/07 17:10:01 WARN TextSocketMicroBatchStream: Stream closed by localhost:8082
# 24/06/07 17:10:01 WARN TextSocketMicroBatchStream: Stream closed by localhost:8083
# 24/06/07 17:10:01 WARN TextSocketMicroBatchStream: Stream closed by localhost:8084

# %%
app = perspective_spark_bridge(
    {
        "machines": machines_widget,
        "usage": usage_widget,
        "status": status_widget,
        "jobs": jobs_widget,
    }
)
port = start_server(app)
# Out:
# CRITICAL:root:Listening on http://localhost:50487
# INFO:     Started server process [34584]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:50487 (Press CTRL+C to quit)
# INFO:     ('127.0.0.1', 50647) - "WebSocket /tables/machines" [accepted]
# INFO:     ('127.0.0.1', 50648) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 50649) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 50650) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 50666) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50668) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 50667) - "WebSocket /tables/machines" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 50670) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50696) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50699) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50700) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50708) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50733) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 50734) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 50736) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50744) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 50771) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 50772) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 50773) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 50801) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50804) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50805) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 50834) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50836) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 50838) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 50868) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50870) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 50869) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 50878) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50904) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50905) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50907) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 50938) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 50941) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 50942) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 50951) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 50952) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 50979) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 50980) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 50982) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51012) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51014) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 51013) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51044) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 51045) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 51046) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51075) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51076) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51078) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51108) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51111) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 51112) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51140) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51143) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 51144) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51173) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 51174) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51176) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51205) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51206) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51208) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51238) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 51239) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 51240) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 51270) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 51271) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 51272) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51280) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51304) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51306) - "WebSocket /tables/usage" [accepted]
# INFO:     connection closed
# INFO:     connection open
# INFO:     ('127.0.0.1', 51308) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51337) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51338) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 51340) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51369) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 51370) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 51372) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51396) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51398) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51400) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51428) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51430) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51432) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51462) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51463) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51464) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51494) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 51496) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 51497) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51528) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 51529) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 51530) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51558) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51560) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51562) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51591) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51594) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 51595) - "WebSocket /tables/usage" [accepted]
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51628) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 51629) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 51630) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51658) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51660) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51662) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51691) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51693) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51695) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51707) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51709) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51732) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51735) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 51736) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 51766) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 51767) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 51768) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 51797) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51799) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51801) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51829) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51831) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51833) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51861) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51864) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51865) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51877) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51898) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51901) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 51902) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51930) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51932) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51934) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51962) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51964) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51966) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 51994) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51996) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 51998) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52027) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52029) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52031) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52060) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52062) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52064) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52072) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52096) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52098) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52100) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52129) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52132) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52133) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52162) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 52163) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52165) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52202) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52203) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 52204) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52286) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 52287) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 52289) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52330) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 52331) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52333) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52374) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52375) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52377) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52418) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 52419) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 52421) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52462) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52464) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52466) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52506) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52509) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52510) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52518) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52556) - "WebSocket /tables/status" [accepted]
# INFO:     ('127.0.0.1', 52557) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     ('127.0.0.1', 52559) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52603) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52605) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52607) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52650) - "WebSocket /tables/jobs" [accepted]
# INFO:     ('127.0.0.1', 52652) - "WebSocket /tables/usage" [accepted]
# INFO:     ('127.0.0.1', 52651) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     connection open
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     ('127.0.0.1', 52701) - "WebSocket /tables/jobs" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52704) - "WebSocket /tables/status" [accepted]
# INFO:     connection open
# INFO:     ('127.0.0.1', 52705) - "WebSocket /tables/usage" [accepted]
# INFO:     connection open
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed
# INFO:     connection closed

# %%
push_to_perspective(machines_df, "machines", "localhost", port)
push_to_perspective(usage_df, "usage", "localhost", port)
push_to_perspective(status_df, "status", "localhost", port)
push_to_perspective(jobs_df, "jobs", "localhost", port)
# Out:
# 24/06/07 17:05:18 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /private/var/folders/pm/0nt85wh51h39f604mgmyyfwm0000gn/T/temporary-87abbd5b-7640-4a46-8981-b94e2e115385. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 24/06/07 17:05:18 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 24/06/07 17:05:18 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /private/var/folders/pm/0nt85wh51h39f604mgmyyfwm0000gn/T/temporary-629e2584-fe4a-40fc-883a-2a20c39d634d. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 24/06/07 17:05:18 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 24/06/07 17:05:18 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /private/var/folders/pm/0nt85wh51h39f604mgmyyfwm0000gn/T/temporary-42209f68-b153-4d6b-a559-942059f819dc. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 24/06/07 17:05:18 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 24/06/07 17:05:18 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /private/var/folders/pm/0nt85wh51h39f604mgmyyfwm0000gn/T/temporary-e65096d7-d5b9-4037-bc46-78225b8fc364. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 24/06/07 17:05:18 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 24/06/07 17:05:19 WARN TextSocketMicroBatchStream: Stream closed by localhost:8081

# %%
status_widget.plugin = "X Bar"
status_widget.group_by = ["status"]
status_widget.columns = ["machine_id"]
status_widget.aggregates = {"status": "last"}

# %%
jobs_widget.group_by = ["machine_id"]
jobs_widget.columns = ["job_id", "name", "units", "start_time", "end_time"],
jobs_widget.aggregates = {"job_id": "count", "name": "last", "units": "sum", "start_time": "last", "end_time": "last"}
